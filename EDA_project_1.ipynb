# %% [markdown]
#
# import numpy as np

# %%
import pandas as pd
from matplotlib import pyplot as plot
import seaborn as sns
import numpy as np

# %%
df1=pd.read_csv(r"C:\Users\sowmya\OneDrive\Desktop\nit_git\demo\students_performance.csv")

# %%
df=df1.copy()

# %%
df1.head()
# Out:
#    Unnamed: 0  Hours_Studied  Attendance Parental_Involvement  \
# 0           0             23          84                  Low
# 1           1             19          64                  Low
# 2           2             24          98               Medium
# 3           3             29          89                  Low
# 4           4             19          92               Medium
#
#   Access_to_Resources Extracurricular_Activities  Sleep_Hours  \
# 0                High                         No            7
# 1              Medium                         No            8
# 2              Medium                        Yes            7
# 3              Medium                        Yes            8
# 4              Medium                        Yes            6
#
#    Previous_Scores Motivation_Level Internet_Access  ...  Family_Income  \
# 0               73              Low             Yes  ...            Low
# ...

# %%
#  #   #-- Please perform Imputation,handle outliers, encoding and feature scaling on the shared dataset

# %%
#imputation :-  refers to the process of replacing missing or null values in a dataset with substitute values


df.isnull().sum()
#Teache_quality - cat
#Parental_Education_Level  - cat
#Distance_from_Home  -- cat
# Out:
# Unnamed: 0                     0
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
df.shape
# Out:
# (6607, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  6607 non-null   int64
#  1   Hours_Studied               6607 non-null   int64
#  2   Attendance                  6607 non-null   int64
#  3   Parental_Involvement        6607 non-null   object
#  4   Access_to_Resources         6607 non-null   object
#  5   Extracurricular_Activities  6607 non-null   object
#  6   Sleep_Hours                 6607 non-null   int64
#  7   Previous_Scores             6607 non-null   int64
#  8   Motivation_Level            6607 non-null   object
#  9   Internet_Access             6607 non-null   object
#  10  Tutoring_Sessions           6607 non-null   int64
#  11  Family_Income               6607 non-null   object
#  12  Teacher_Quality             6529 non-null   object
# ...

# %%
df["Parental_Education_Level"]
# Out:
# 0        High School
# 1            College
# 2       Postgraduate
# 3        High School
# 4            College
#             ...
# 6602     High School
# 6603     High School
# 6604    Postgraduate
# 6605     High School
# 6606    Postgraduate
# Name: Parental_Education_Level, Length: 6607, dtype: object

# %%
df["Teacher_Quality"]
# Out:
# 0       Medium
# 1       Medium
# 2       Medium
# 3       Medium
# 4         High
#          ...
# 6602    Medium
# 6603      High
# 6604    Medium
# 6605    Medium
# 6606    Medium
# Name: Teacher_Quality, Length: 6607, dtype: object

# %%
df["Distance_from_Home"]
# Out:
# 0           Near
# 1       Moderate
# 2           Near
# 3       Moderate
# 4           Near
#           ...
# 6602        Near
# 6603        Near
# 6604        Near
# 6605         Far
# 6606        Near
# Name: Distance_from_Home, Length: 6607, dtype: object

# %%
df.head()
# Out:
#    Unnamed: 0  Hours_Studied  Attendance Parental_Involvement  \
# 0           0             23          84                  Low
# 1           1             19          64                  Low
# 2           2             24          98               Medium
# 3           3             29          89                  Low
# 4           4             19          92               Medium
#
#   Access_to_Resources Extracurricular_Activities  Sleep_Hours  \
# 0                High                         No            7
# 1              Medium                         No            8
# 2              Medium                        Yes            7
# 3              Medium                        Yes            8
# 4              Medium                        Yes            6
#
#    Previous_Scores Motivation_Level Internet_Access  ...  Family_Income  \
# 0               73              Low             Yes  ...            Low
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='object')

# %%
df.drop("Unnamed: 0",axis=1,inplace=True)

# %%
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
t_mode=df["Teacher_Quality"].mode().values[0]
p_mode=df["Parental_Education_Level"].mode().values[0]
d_mode=df["Distance_from_Home"].mode().values[0]

# %%
print(t_mode)
print(p_mode)
print(d_mode)
# Out:
# Medium
# High School
# Near

# %%
plot.figure(figsize=(25,5))
plot.subplot(1,3,1)
sns.boxplot(df["Teacher_Quality"])
plot.subplot(1,3,2)
sns.boxplot(df["Parental_Education_Level"])
plot.subplot(1,3,3)
sns.boxplot(df["Distance_from_Home"])
# Out:
# <Axes: ylabel='Distance_from_Home'>

# %%
df["Teacher_Quality"].fillna(t_mode,inplace=True)
# Out:
# C:\Users\sowmya\AppData\Local\Temp\ipykernel_17648\3601316940.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Teacher_Quality"].fillna(t_mode,inplace=True)

# %%
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
df["Teacher_Quality"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Parental_Education_Level"].fillna(p_mode,inplace = True)
# Out:
# C:\Users\sowmya\AppData\Local\Temp\ipykernel_17648\572348653.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Parental_Education_Level"].fillna(p_mode,inplace = True)

# %%
df["Parental_Education_Level"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Distance_from_Home"].fillna(d_mode,inplace=True)
# Out:
# C:\Users\sowmya\AppData\Local\Temp\ipykernel_17648\1570121179.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Distance_from_Home"].fillna(d_mode,inplace=True)

# %%
df["Distance_from_Home"].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Hours_Studied                 0
# Attendance                    0
# Parental_Involvement          0
# Access_to_Resources           0
# Extracurricular_Activities    0
# Sleep_Hours                   0
# Previous_Scores               0
# Motivation_Level              0
# Internet_Access               0
# Tutoring_Sessions             0
# Family_Income                 0
# Teacher_Quality               0
# School_Type                   0
# Peer_Influence                0
# Physical_Activity             0
# Learning_Disabilities         0
# Parental_Education_Level      0
# Distance_from_Home            0
# Gender                        0
# Exam_Score                    0
# dtype: int64

# %%
# -- Outliers are data points in a dataset that are significantly different from the majority of the data.

# %%
sns.boxplot
# Out:
# <function seaborn.categorical.boxplot(data=None, *, x=None, y=None, hue=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, fill=True, dodge='auto', width=0.8, gap=0, whis=1.5, linecolor='auto', linewidth=None, fliersize=None, hue_norm=None, native_scale=False, log_scale=None, formatter=None, legend='auto', ax=None, **kwargs)>

# %%
df.dtypes
# Out:
# Hours_Studied                  int64
# Attendance                     int64
# Parental_Involvement          object
# Access_to_Resources           object
# Extracurricular_Activities    object
# Sleep_Hours                    int64
# Previous_Scores                int64
# Motivation_Level              object
# Internet_Access               object
# Tutoring_Sessions              int64
# Family_Income                 object
# Teacher_Quality               object
# School_Type                   object
# Peer_Influence                object
# Physical_Activity              int64
# Learning_Disabilities         object
# Parental_Education_Level      object
# Distance_from_Home            object
# Gender                        object
# Exam_Score                     int64
# dtype: object

# %%
df.select_dtypes(include="number").columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Sleep_Hours', 'Previous_Scores',
#        'Tutoring_Sessions', 'Physical_Activity', 'Exam_Score'],
#       dtype='object')

# %%
# find outliers 
plot.figure(figsize=(20,10))
plot.subplot(1,7,1)
sns.boxenplot(df["Hours_Studied"])
plot.subplot(1,7,2)
sns.boxenplot(df["Attendance"])
plot.subplot(1,7,3)
sns.boxenplot(df["Sleep_Hours"])
plot.subplot(1,7,4)
sns.boxenplot(df["Previous_Scores"])
plot.subplot(1,7,5)
sns.boxenplot(df["Tutoring_Sessions"])
plot.subplot(1,7,6)
sns.boxenplot(df["Physical_Activity"])
plot.subplot(1,7,7)
sns.boxenplot(df["Exam_Score"])
# Out:
# <Axes: ylabel='Exam_Score'>

# %%
# outliers columns  
#1)Hours_Studied
#5)Tutoring_Sessions
#7)Exam_Score

# %%
a=df["Hours_Studied"].describe()
q1=int(a["25%"])
q3=int(a["75%"])
iqr=q3-q1
print(a,q1,q3,iqr)
# Out:
# count    6607.000000
# mean       19.975329
# std         5.990594
# min         1.000000
# 25%        16.000000
# 50%        20.000000
# 75%        24.000000
# max        44.000000
# Name: Hours_Studied, dtype: float64 16 24 8

# %%
lower_limit=q1-1.5*iqr
upper_limit=q3+1.5*iqr

# %%
print(lower_limit,upper_limit)
# Out:
# 4.0 36.0

# %%
df["Hours_Studied"].clip(lower_limit,upper_limit,inplace=True)
# Out:
# C:\Users\sowmya\AppData\Local\Temp\ipykernel_17648\3576005813.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Hours_Studied"].clip(lower_limit,upper_limit,inplace=True)

# %%
sns.boxplot(df["Hours_Studied"])
# Out:
# <Axes: ylabel='Hours_Studied'>

# %%
a=df["Tutoring_Sessions"].describe()
q1=int(a["25%"])
q3=int(a["75%"])
iqr=q3-q1
print(a,q1,q3,iqr)
# Out:
# count    6607.000000
# mean        1.493719
# std         1.230570
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         8.000000
# Name: Tutoring_Sessions, dtype: float64 1 2 1

# %%
lower_limit_1=q1-1.5*iqr
upper_limit_1=q3+1.5*iqr

# %%
print(lower_limit_1,upper_limit_1)
# Out:
# -0.5 3.5

# %%
df["Tutoring_Sessions"].clip(lower_limit_1,upper_limit_1,inplace=True)
# Out:
# C:\Users\sowmya\AppData\Local\Temp\ipykernel_17648\3650676973.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Tutoring_Sessions"].clip(lower_limit_1,upper_limit_1,inplace=True)
# C:\Users\sowmya\AppData\Local\Temp\ipykernel_17648\3650676973.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
# ...

# %%
a=df["Exam_Score"].describe()
q1=int(a["25%"])
q3=int(a["75%"])
iqr=q3-q1
print(a,q1,q3,iqr)
# Out:
# count    6607.000000
# mean       67.235659
# std         3.890456
# min        55.000000
# 25%        65.000000
# 50%        67.000000
# 75%        69.000000
# max       101.000000
# Name: Exam_Score, dtype: float64 65 69 4

# %%
lower_limit=q1-1.5*iqr
upper_limit=q3+1.5*iqr
print(upper_limit)
print(lower_limit)
# Out:
# 75.0
# 59.0

# %%
df["Exam_Score"].clip(lower_limit,upper_limit,inplace=True)
# Out:
# C:\Users\sowmya\AppData\Local\Temp\ipykernel_17648\4134541864.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Exam_Score"].clip(lower_limit,upper_limit,inplace=True)

# %%
df.loc[50:100,"Exam_Score"]
# Out:
# 50     64
# 51     64
# 52     67
# 53     67
# 54     66
# 55     72
# 56     65
# 57     71
# 58     66
# 59     68
# 60     70
# 61     62
# 62     68
# 63     67
# 64     71
# 65     68
# 66     69
# 67     70
# 68     69
# 69     65
# 70     70
# 71     71
# 72     65
# 73     72
# 74     69
# 75     66
# 76     68
# 77     65
# 78     64
# 79     60
# 80     65
# 81     66
# 82     74
# 83     62
# 84     70
# 85     69
# 86     67
# 87     64
# 88     71
# 89     68
# 90     64
# 91     63
# 92     71
# 93     69
# 94     75
# 95     68
# 96     62
# 97     68
# 98     66
# 99     64
# 100    67
# Name: Exam_Score, dtype: int64

# %%
plot.figure(figsize=(20,10))
plot.subplot(1,7,1)
sns.boxplot(df["Hours_Studied"])
plot.subplot(1,7,2)
sns.boxplot(df["Attendance"])
plot.subplot(1,7,3)
sns.boxplot(df["Sleep_Hours"])
plot.subplot(1,7,4)
sns.boxplot(df["Previous_Scores"])
plot.subplot(1,7,5)
sns.boxplot(df["Tutoring_Sessions"])
plot.subplot(1,7,6)
sns.boxplot(df["Physical_Activity"])
plot.subplot(1,7,7)
sns.boxplot(df["Exam_Score"])
# Out:
# <Axes: ylabel='Exam_Score'>

# %%
# encoding :Encoding refers to converting categorical (non-numeric) data into a numerical format so that machine learning models can process it. 
# Categorical data can either be ordinal (with an inherent order, like "low," "medium," "high") or nominal (without an order, like "red," "green," "blue").
#  Machine learning models cannot work directly with these non-numeric categories, so encoding transforms them into numeric representations.


# feature scaling  :Feature scaling is the process of normalizing or standardizing the range of features in your data to ensure that they are on the same scale. 
# Many machine learning algorithms perform better when the input data is scaled because certain algorithms (especially distance-based ones like k-nearest neighbors or 
# gradient-based methods like neural networks) are sensitive to the magnitude of the features.

# %%
#encoding
# nominaldata
df["Extracurricular_Activities"].value_counts()
# Out:
# Extracurricular_Activities
# Yes    3938
# No     2669
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
df = pd.get_dummies(df, columns=["Motivation_Level", "Family_Income", "Teacher_Quality", "Peer_Influence", "Parental_Education_Level", "Distance_from_Home"], dtype="int64", drop_first=False)

# %%
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores Internet_Access  \
# ...

# %%
df.select_dtypes(include=["object"])
# Out:
#      Parental_Involvement Access_to_Resources Extracurricular_Activities  \
# 0                     Low                High                         No
# 1                     Low              Medium                         No
# 2                  Medium              Medium                        Yes
# 3                     Low              Medium                        Yes
# 4                  Medium              Medium                        Yes
# ...                   ...                 ...                        ...
# 6602                 High              Medium                         No
# 6603                 High              Medium                         No
# 6604               Medium                 Low                        Yes
# 6605                 High                High                        Yes
# 6606               Medium                 Low                        Yes
#
#      Internet_Access School_Type Learning_Disabilities  Gender
# ...

# %%
df["Motivation_Level_Low"].value_counts()
# Out:
# Motivation_Level_Low
# 0    4670
# 1    1937
# Name: count, dtype: int64

# %%
df["Extracurricular_Activities"].value_counts()
#dumme
# Out:
# Extracurricular_Activities
# Yes    3938
# No     2669
# Name: count, dtype: int64

# %%
df["Internet_Access"].value_counts()
#dummy
# Out:
# Internet_Access
# Yes    6108
# No      499
# Name: count, dtype: int64

# %%
df["School_Type"].value_counts()
#dummy
# Out:
# School_Type
# Public     4598
# Private    2009
# Name: count, dtype: int64

# %%
df["Learning_Disabilities"].value_counts()
#dummy
# Out:
# Learning_Disabilities
# No     5912
# Yes     695
# Name: count, dtype: int64

# %%
df["Gender"].value_counts()
#dummy
# Out:
# Gender
# Male      3814
# Female    2793
# Name: count, dtype: int64

# %%
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores Internet_Access  \
# ...

# %%
# ordinal columns 
# -- Motivation_Level,Family_Income,Teacher_Quality,Peer_Influence,Parental_Education_Level,Distance_from_Home

# %%
df["Parental_Involvement"].value_counts()
# Out:
# Parental_Involvement
# Medium    3362
# High      1908
# Low       1337
# Name: count, dtype: int64

# %%
d1={"Low":1,"High":2,"Medium":3}
df["Parental_Involvement"]=df["Parental_Involvement"].str.strip()
df["Parental_Involvement"]=df["Parental_Involvement"].map(d1)

# %%
df["Access_to_Resources"].value_counts()
# Out:
# Access_to_Resources
# Medium    3319
# High      1975
# Low       1313
# Name: count, dtype: int64

# %%
d2={"Low":1,"Medium":2,"High":3}
df["Access_to_Resources"]=df["Access_to_Resources"].str.strip()
df["Access_to_Resources"]=df["Access_to_Resources"].map(d2)

# %%
df=pd.get_dummies(df,columns=["Extracurricular_Activities","Internet_Access"],dtype="int64",drop_first=False)

# %%
df
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                     1                    3
# 1                19          64                     1                    2
# 2                24          98                     3                    2
# 3                29          89                     1                    2
# 4                19          92                     3                    2
# ...             ...         ...                   ...                  ...
# 6602             25          69                     2                    2
# 6603             23          76                     2                    2
# 6604             20          90                     3                    1
# 6605             10          86                     2                    3
# 6606             15          67                     3                    1
#
#       Sleep_Hours  Previous_Scores  Tutoring_Sessions School_Type  \
# ...

# %%
df["School_Type"].value_counts()
# Out:
# School_Type
# Public     4598
# Private    2009
# Name: count, dtype: int64

# %%
df=pd.get_dummies(df,columns=["School_Type","Learning_Disabilities"],dtype="int64",drop_first=False)

# %%
df=pd.get_dummies(df,columns=["Gender"],dtype="int64",drop_first=False)

# %%
df
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                     1                    3
# 1                19          64                     1                    2
# 2                24          98                     3                    2
# 3                29          89                     1                    2
# 4                19          92                     3                    2
# ...             ...         ...                   ...                  ...
# 6602             25          69                     2                    2
# 6603             23          76                     2                    2
# 6604             20          90                     3                    1
# 6605             10          86                     2                    3
# 6606             15          67                     3                    1
#
# ...
